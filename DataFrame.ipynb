# %% [markdown]
# ## Dataframe Basics

# %%
import pandas as pd
df=pd.read_csv("dataset.csv")
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#to fill null values
df.fillna(0,inplace=True)
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.shape
# Out:
# (5110, 12)

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   0.0     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   0.0     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
df.tail(1) #prints last element
# Out:
#          id  gender   age  hypertension  heart_disease ever_married work_type  \
# 5109  44679  Female  44.0             0              0          Yes  Govt_job
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 5109          Urban              85.28  26.2        Unknown       0

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
df['stroke']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: int64

# %%
type(df['stroke'])
# Out:
# pandas.core.series.Series

# %%
df[['gender','age','stroke']]
# Out:
#       gender   age  stroke
# 0       Male  67.0       1
# 1     Female  61.0       1
# 2       Male  80.0       1
# 3     Female  49.0       1
# 4     Female  79.0       1
# ...      ...   ...     ...
# 5105  Female  80.0       0
# 5106  Female  81.0       0
# 5107  Female  35.0       0
# 5108    Male  51.0       0
# 5109  Female  44.0       0
#
# [5110 rows x 3 columns]

# %%
df['age'].max() #print max age
# Out:
# 82.0

# %%
df['age'].std() #standard deviation
# Out:
# 22.61264672311352

# %%
df.describe() #prints the statistics of the data
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  5110.000000  5110.000000
# mean          106.147677    27.756732     0.048728
# std            45.283560     9.529497     0.215320
# min            55.120000     0.000000     0.000000
# 25%            77.245000    22.900000     0.000000
# 50%            91.885000    27.700000     0.000000
# ...

# %%
df[df.age>=50]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5100  68398    Male  82.0             1              0          Yes
# 5102  45010  Female  57.0             0              0          Yes
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df[df.bmi==df.bmi.max()]
      #OR
df[df.bmi==df['bmi'].max()] #sometimes column name are sepearated by spaces, so the above syntax will not.
# Out:
#          id gender   age  hypertension  heart_disease ever_married work_type  \
# 2128  56420   Male  17.0             1              0           No   Private
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 2128          Rural              61.67  97.6        Unknown       0

# %%
df[['id','age','stroke']][df.bmi==df['bmi'].max()] #to select specific column
# Out:
#          id   age  stroke
# 2128  56420  17.0       0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5110, step=1)

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.set_index('id')
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0             0              1          Yes        Private
# 51676  Female  61.0             0              0          Yes  Self-employed
# 31112    Male  80.0             0              1          Yes        Private
# 60182  Female  49.0             0              0          Yes        Private
# 1665   Female  79.0             1              0          Yes  Self-employed
# ...       ...   ...           ...            ...          ...            ...
# 18234  Female  80.0             1              0          Yes        Private
# 44873  Female  81.0             0              0          Yes  Self-employed
# 19723  Female  35.0             0              0          Yes  Self-employed
# 37544    Male  51.0             0              0          Yes        Private
# 44679  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
df # the above data is not permanently modified
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.set_index('id',inplace=True) #now permanently modified

# %%
df
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0             0              1          Yes        Private
# 51676  Female  61.0             0              0          Yes  Self-employed
# 31112    Male  80.0             0              1          Yes        Private
# 60182  Female  49.0             0              0          Yes        Private
# 1665   Female  79.0             1              0          Yes  Self-employed
# ...       ...   ...           ...            ...          ...            ...
# 18234  Female  80.0             1              0          Yes        Private
# 44873  Female  81.0             0              0          Yes  Self-employed
# 19723  Female  35.0             0              0          Yes  Self-employed
# 37544    Male  51.0             0              0          Yes        Private
# 44679  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
df.loc[9046] #we can now access using index id rather than the row number
# Out:
# gender                          Male
# age                             67.0
# hypertension                       0
# heart_disease                      1
# ever_married                     Yes
# work_type                    Private
# Residence_type                 Urban
# avg_glucose_level             228.69
# bmi                             36.6
# smoking_status       formerly smoked
# stroke                             1
# Name: 9046, dtype: object

# %%
df.reset_index(inplace=True) 
df
# Out:
#       index     id  gender   age  hypertension  heart_disease ever_married  \
# 0         0   9046    Male  67.0             0              1          Yes
# 1         1  51676  Female  61.0             0              0          Yes
# 2         2  31112    Male  80.0             0              1          Yes
# 3         3  60182  Female  49.0             0              0          Yes
# 4         4   1665  Female  79.0             1              0          Yes
# ...     ...    ...     ...   ...           ...            ...          ...
# 5105   5105  18234  Female  80.0             1              0          Yes
# 5106   5106  44873  Female  81.0             0              0          Yes
# 5107   5107  19723  Female  35.0             0              0          Yes
# 5108   5108  37544    Male  51.0             0              0          Yes
# 5109   5109  44679  Female  44.0             0              0          Yes
#
# ...
