# %% [markdown]
# # Matplotlib & Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# %matplotlib inline  is to ensure that plots are shown and embedded with the jupyter notebook itself. Without this command,sometimes plots may show up in pop-up windows

# %% [markdown]
# ## Line chart

# %%
yield_apples=[0.895,0.91,0.919,0.926,0.929,0.931]
plt.plot(yield_apples);

# %%
years=[2010,2011,2012,2013,2014,2015]
plt.plot(years,yield_apples);

# %%
plt.plot(years,yield_apples);
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');
#order of the code does'nt matter as long as they are written on same cell

# %%
years=range(2000,2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896 ]

# %%
plt.plot(years,apples)
plt.plot(years,oranges)

plt.xlabel('year')
plt.ylabel('yield (tons per hectare)');

# %%
# Chart Title and Legend
plt.plot(years,apples)
plt.plot(years,oranges)

plt.xlabel('year')
plt.ylabel('yield (tons per hectare)')

plt.title("crop yield in Kanto")
plt.legend(['Apples','Oranges']);

# %%
# Line Markers
plt.plot(years,apples,marker='o')
plt.plot(years,oranges,marker='x')

plt.xlabel('year')
plt.ylabel('yield (tons per hectare)')

plt.title("crop yield in Kanto")
plt.legend(['Apples','Oranges']);

# %% [markdown]
# ### Styling lines and markers
# The plt.plot function supports many arguments for styling lines and markers:
#
#     color or c: Set the color of the line
#     linestyle or ls: Choose between a solid or dashed line
#     linewidth or lw: Set the width of a line
#     markersize or ms: Set the size of markers
#     markeredgecolor or mec: Set the edge color for markers
#     markeredgewidth or mew: Set the edge width for markers
#     markerfacecolor or mfc: Set the fill color for markers
#     alpha: Opacity of the plot

# %%
plt.plot(years, apples, marker='s', c='b', ls='-', lw=2, ms=8, mew=4, mec='navy')
plt.plot(years, oranges, marker='o', c='r', ls='--', lw=3, ms=10, alpha=0.5)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# The fmt argument provides a shorthand for specifying the marker shape, line style, and line color. It can be provided as the third argument to plt.plot.
#
# fmt = '[marker][line][color]'

# %%
plt.plot(years,apples,'s-b') #square marker,solid line,brown colour
plt.plot(years,oranges,'o--r') #circular marker,dashed line,red colour
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# ### Changing the figure Size

# %%
plt.figure(figsize=(12,6))
plt.plot(years,oranges,'or') 
plt.title("Yield of Oranges (tons per hectare)");

# %% [markdown]
# ### Improving default styles using Seaborn

# %%
sns.set_style('whitegrid')

# %%
plt.plot(years,apples,'s-b') 
plt.plot(years,oranges,'o--r') 
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %%
sns.set_style("darkgrid")

# %%
plt.plot(years,apples,'s-b') 
plt.plot(years,oranges,'o--r') 
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %%
plt.plot(years,oranges,'or')
plt.title("Yield of Oranges (tons per hectare)");

# %% [markdown]
# we can edit the default styles of matplotlib by modifying matplotlib.rcparams dictionaru

# %%
import matplotlib
matplotlib.rcParams['font.size']=14
matplotlib.rcParams['figure.figsize']=(9,5)
matplotlib.rcParams['figure.facecolor']='#00000000'

# %%
plt.plot(years,oranges,'or')
plt.title("Yield of Oranges (tons per hectare)");

# %% [markdown]
# ## Scatter Plot

# %%
df=sns.load_dataset("iris") #default dataset in sns

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(df.sepal_length,df.sepal_width)

# %% [markdown]
# The output is not very informative as there are too many combinations of the two properties within the dataset.
# There doesn't seem to be simple relationship between them.
# We can use a scatter plot to visualize how sepal length & sepal width vary using the scatterplot function from
# the seaborn module

# %%
sns.scatterplot(x=df.sepal_length,y=df.sepal_width);

# %% [markdown]
# #### Adding Hues

# %%
sns.scatterplot(x=df.sepal_length,y=df.sepal_width,hue=df.species);

# %% [markdown]
# ### Customising Seaborn Figures

# %% [markdown]
# Since Seaborn uses Matplotlib's plotting functions internally, we can use functions like plt.figure and
# plt.title to modify the figure.

# %%
plt.figure(figsize=(12, 6))
plt.title('Sepal Dimensions')
sns.scatterplot(x=df.sepal_length,
y=df.sepal_width,
hue=df.species,
s=100);

# %% [markdown]
# ### Plotting using Pandas Data Frames

# %% [markdown]
# Seaborn has in-built support for Pandas data frames. Instead of passing each column as a series, you can provide
# column names and use the data argument to specify a data frame.

# %%
plt.title('Sepal Dimensions')
sns.scatterplot(x='sepal_length',y='sepal_width',hue='species',s=100,data=df);

# %% [markdown]
# ## Histogram

# %% [markdown]
# A histogram represents the distribution of a variable by creating bins (interval) along the range of values and
# showing vertical bars to indicate the number of observations in each bin

# %%
df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.title("Distribution of sepal width")
plt.hist(df.sepal_width);

# %%
# Controlling size and number of bins
plt.hist(df.sepal_width,bins=5);

# %%
import numpy as np

#Specifying boundary of each bin
plt.hist(df.sepal_width,bins=np.arange(2,5,0.25));

# %%
#Bins of unequal sizes
plt.hist(df.sepal_width,bins=[1,3,4,4.5]);

# %% [markdown]
# ### Multiple Histograms

# %%
setosa_df = df[df.species == 'setosa']
versicolor_df = df[df.species == 'versicolor']
virginica_df = df[df.species == 'virginica']

# %%
plt.hist(setosa_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));

# %%
plt.title('Distribution of Sepal Width')
plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width],bins=np.arange(2,5,0.25),stacked=True);
plt.legend(['Setosa', 'Versicolor', 'Virginica']);

# %% [markdown]
# ## Bar Chart

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]
plt.bar(years,oranges);

# %%
plt.bar(years,apples)
plt.bar(years,oranges,bottom=apples);

# %% [markdown]
# ### Bar plots with Averages

# %%
tips_df=sns.load_dataset('tips');

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x='day',y='total_bill',data=tips_df);

# %% [markdown]
# The lines cutting each bar represent the amount of variation in the values. For instance, it seems like the variation
# in the total bill is relatively high on Fridays and low on Saturday

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=tips_df);

# %% [markdown]
# You can make the bars horizontal simply by switching the axes.

# %%
sns.barplot(x='total_bill',y='day',hue='sex',data=tips_df);

# %% [markdown]
# ## Heatmap

# %%
flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")
flights_df
# Out:
# C:\Users\mahes\AppData\Local\Temp\ipykernel_9580\1940392331.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# ...

# %%
plt.title("No. of Passengers (1000s)")
sns.heatmap(flights_df);

# %% [markdown]
# We can also display the actual values in each block by specifying annot=True and using the cmap argument to
# change the color palette.

# %%
plt.title("No. of Passengers (1000s)")
sns.heatmap(flights_df, fmt="d", annot=True, cmap='Blues');

# %% [markdown]
# ### Pair plots with Seaborn

# %% [markdown]
# Seaborn also provides a helper function sns.pairplot to automatically plot several different charts for pairs of
# features within a dataframe.

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df, hue='species');

# %%
sns.pairplot(tips_df, hue='sex');

# %% [markdown]
# ## Images
